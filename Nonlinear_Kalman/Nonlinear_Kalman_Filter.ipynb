# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import scipy
from myFuncs import *

plot_observation('data/studentdata0.mat')
plot_observation3D('data/studentdata0.mat')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import matplotlib.pyplot as plt
#       4 import scipy
# ----> 5 from myFuncs import *
#       7 plot_observation('data/studentdata0.mat')
#       8 plot_observation3D('data/studentdata0.mat')
#
# File ~/Desktop/RBE 595 Advanced Robotic Navigation/Advanced-Robotic-Navigation/Nonlinear_Kalman/myFuncs.py:176
#     <a href='file:///Users/paulcrann/Desktop/RBE%20595%20Advanced%20Robotic%20Navigation/Advanced-Robotic-Navigation/Nonlinear_Kalman/myFuncs.py?line=172'>173</a>     plt.legend()
#     <a href='file:///Users/paulcrann/Desktop/RBE%20595%20Advanced%20Robotic%20Navigation/Advanced-Robotic-Navigation/Nonlinear_Kalman/myFuncs.py?line=173'>174</a>     plt.show()
# ...

# %%
path = 'data/studentdata1.mat'
plot_observation(path)
plot_observation3D(path)

# %%
path = 'data/studentdata2.mat'
plot_observation(path)
plot_observation3D(path)

# %%
path = 'data/studentdata3.mat'
plot_observation(path)
plot_observation3D(path)

# %%
path = 'data/studentdata4.mat'
plot_observation(path)
plot_observation3D(path)
